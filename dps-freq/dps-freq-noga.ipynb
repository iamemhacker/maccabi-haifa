# %%
from toolkit.utils import read_data, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured time.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Noga (Fly)

# %%
display_analysis(read_data("_data/raw-data.csv", "Noga"))
# Out:
#    Swimmer Name  Freq  Cycle time  Num strokes   Time
# 41         Noga  38.7    1.550000           10  15.50
# 45         Noga  40.3    1.490000           10  14.90
# 42         Noga  41.3    1.452000           10  14.52
# 44         Noga  42.6    1.409000           10  14.09
# 46         Noga  42.9    1.398000           10  13.98
# 50         Noga  48.1    1.247273           11  13.72
# 47         Noga  44.2    1.358000           10  13.58
# 43         Noga  44.2    1.357000           10  13.57
# 49         Noga  49.5    1.210909           11  13.32
# 48         Noga  45.8    1.311000           10  13.11
#                  Freq  Num strokes
# Freq         1.000000     0.788872
# Num strokes  0.788872     1.000000
#              Num strokes      Time
# Num strokes     1.000000 -0.359032
# Time           -0.359032  1.000000

# %% [markdown]
# ## Noga 25m Fly
# * Stroke-count: 11
# * DPS: 1.63 m/stroke
# * Frequency: 45.8 strokes/minute
# * Time: 16.07s

# %% [markdown]
# <video width="500" height="240"
#        src="_data/noga_s5_1.mp4"
#        controls>
# </video>

# %% [markdown]
# ## Sara Sjoestroem's 50 fly final, Fukuoka 2023
# * Stroke-count: 21
# * DPS: 1.67 m/stroke
# * Frequency: 63 strokes/minute
# * Time: 24.77s

# %% [markdown]
# <video width="500" height="240"
#        src="_data/sarah_50fly_final.mp4"
#        controls>
# </video>

# %% [markdown]
# ## Sarah Sjoestroem's 100 final, Rio 2016

# %% [markdown]
# * DPS: 1.67 m/stroke
# * Frequency: 50 storkes/sec
# * Time: 55.3s (WR)

# %% [markdown]
# <video width="500" height="240"
#        src="_data/sarah_100fly_final.mp4"
#        controls>
# </video>

# %% [markdown]
# # Insights

# %% [markdown]
# 1. Noga was good at maintaining her DPS, in the face of frequency increase.
# 1. There place of frequency-DPS-speed is *almost* planar, which suggest Noga does not have a frequency week-spot.
# 1. I think we need to work on Noga's ability to swim on higher frequencies. The frequency of the last (fith) set was suppose to be on a 50 strokes-per-minute, whereas only one lap was actually near that target frequency. In light of the fact that Noga is actually **gaining** speed in this frequency, it would be nice to see her produce these 100-pace more naturally.
# 1. Noga's DPS ranges between $1.63-1.68$ which is *very* good. It would be nice to see Noga feel more comfortable on those higher frequencies, so we would be able to gain more speed. (_e.g._, maintaining a DPS of 1.65 with a frequency of 50 $cycles/minute$ yeilds a speed of $1.375\frac{m}{sec}$), which with a reasonable underwater brings us to $\sim32s$ for 50 fly.
