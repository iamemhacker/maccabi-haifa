# %%
from toolkit.utils import read_data_new, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured time.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Arthur (Breast stroke)

# %%
display_analysis(read_data_new("_data/raw-data-new.xlsx", "Arthur"))
# Out:
#    Swimmer Name  uw distance  uw time   Time  Num strokes  Cycle time  \
# 12       Arthur         11.8     7.88  17.20          7.0    1.331429
# 10       Arthur         12.0     7.60  17.00          7.0    1.342857
# 13       Arthur         11.8     7.47  17.10          7.0    1.375714
# 11       Arthur         11.5     7.60  17.50          7.0    1.414286
# 9        Arthur         11.0     6.00  16.53          8.0    1.316250
# 14       Arthur         11.5     7.55  17.78          8.0    1.278750
# 8        Arthur         12.0     6.50  16.50          7.0    1.428571
#
#          Freq       DPS     Speed
# 12  45.064378  1.885714  1.416309
# 10  44.680851  1.857143  1.382979
# 13  43.613707  1.885714  1.370717
# 11  42.424242  1.928571  1.363636
# 9   45.584046  1.750000  1.329535
# 14  46.920821  1.687500  1.319648
# 8   42.000000  1.857143  1.300000
#                  Freq  Num strokes
# Freq         1.000000     0.748693
# Num strokes  0.748693     1.000000
# ...

# %% [markdown]
# ## Arthur 25m B.S.
# * Cycles: 7
# * DPC (Distance-per-cycle): 1.85 m/cycle
# * Frequency: 42.0 strokes/minute
# * Time: 16.5s

# %% [markdown]
# ## Arthur 25m B.S.
# * \# of Cycles: 15
# * DPC (Distance-per-cycle): 1.68 m/cycle
# * Frequency: 46.9 strokes/minute
# * Time: 17.78s

# %% [markdown]
# ## Zsch Stubblety-Cook
# * \# of Cycles: 15
# * DPC: 2.46 m/stroke
# * Frequency: 42.3 strokes/minute
# * Time: 28.2s

# %% [markdown]
# # Insights

# %% [markdown]
# 1. Good UW! That wasn't the purpose, but seeing an effortless uw from a push on $v \ge 3\frac{m}{sec}$ is encouraging.
# 1. At appears that Arthur's comfort zone is at the lower-frequencies ($\sim42\frac{strokes}{minute}$).
# 1. Increasing stroke-frequency to $f \ge 45$ doesn't necessarily yeilds increased speed, we would like to how we can improve that.
# 1. It would be nice to see Arthur increase his DPS (at the lower frequencies for startes) to $dps \approx 2\frac{strokes}{minute}$
