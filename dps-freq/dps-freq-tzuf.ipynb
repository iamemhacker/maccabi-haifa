# %%
from toolkit.utils import read_data, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured time.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Tzuf (Fly)

# %%
display_analysis(read_data("_data/raw-data.csv", "Tzuf"))
# Out:
#    Swimmer Name  Freq  Cycle time  Num strokes   Time
# 21         Tzuf  50.0       1.200           10  16.60
# 23         Tzuf  52.6       1.140           10  16.00
# 20         Tzuf  46.9       1.280            9  15.75
# 27         Tzuf  55.6       1.080           10  15.50
# 22         Tzuf  51.3       1.170            9  15.34
# 24         Tzuf  53.6       1.120            9  15.00
# 25         Tzuf  49.2       1.220            9  14.95
# 26         Tzuf  43.6       1.375            8  14.80
# 28         Tzuf  53.6       1.120           10  14.70
#                  Freq  Num strokes
# Freq         1.000000     0.757764
# Num strokes  0.757764     1.000000
#              Num strokes      Time
# Num strokes     1.000000  0.503462
# Time            0.503462  1.000000

# %% [markdown]
# ## Tzuf 25m Fly
# * Stroke-count: 9
# * DPS: 1.7 m/stroke
# * Frequency: 43.6 strokes/minute
# * Time: 14.8s

# %% [markdown]
# <video width="500" height="240"
#        src="_data/tzuf_best.mp4"
#        controls>
# </video>

# %% [markdown]
# ## Sara Sjoestroem's 50 fly final, Fukuoka 2023
# * Stroke-count: 21
# * DPS: 1.67 m/stroke
# * Frequency: 63 strokes/minute
# * Time: 24.77s

# %% [markdown]
# <video width="500" height="240"
#        src="_data/sarah_50fly_final.mp4"
#        controls>
# </video>

# %% [markdown]
# ## Sarah Sjoestroem's 100 final, Rio 2016

# %% [markdown]
# * DPS: 1.67 m/stroke
# * Frequency: 50 storkes/sec
# * Time: 55.3s (WR)

# %% [markdown]
# <video width="500" height="240"
#        src="_data/sarah_100fly_final.mp4"
#        controls>
# </video>

# %% [markdown]
# # Insights

# %% [markdown]
# 1. Tzuf clocked $14.8$ with a 200-pace frequency, and 8 strokes. That's encouraging - clearly, the potential is there.
# 1. Tzuf shows a lot of dicipline with the cycle frequency, it seems that working on high paces ($F \ge 50 strokes/minute$) shouldn't be a problem.
# 1. It would be great to see Tzuf improving her DPS. We need more consistency in this area.
#    IMHO, it would help Tzuf both in practice, and in her ability to replicate results in reaces (prelims and finals alike).
