# %%
from toolkit.utils import read_data, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured time.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Alon (Freestyle)

# %%
display_analysis(read_data("_data/raw-data.csv", "Alon"))
# Out:
#    Swimmer Name  Freq  Cycle time  Num strokes   Time
# 52         Alon  39.7    1.510526          9.5  14.35
# 55         Alon  42.4    1.415000         10.0  14.15
# 51         Alon  38.2    1.571111          9.0  14.14
# 56         Alon  45.6    1.317143         10.5  13.83
# 53         Alon  43.5    1.380000         10.0  13.80
# 58         Alon  43.6    1.376000         10.0  13.76
# 61         Alon  48.1    1.248571         10.5  13.11
# 59         Alon  48.1    1.247619         10.5  13.10
# 54         Alon  46.2    1.299000         10.0  12.99
# 57         Alon  46.3    1.297000         10.0  12.97
# 60         Alon  49.5    1.212000         10.0  12.12
#                  Freq  Num strokes
# Freq         1.000000     0.806448
# Num strokes  0.806448     1.000000
#              Num strokes      Time
# Num strokes     1.000000 -0.428083
# Time           -0.428083  1.000000

# %% [markdown]
# ## Alon 25m Free
# * Cycles: 10
# * DPC (Distance-per-cycle): 1.95 m/cycle
# * Frequency: 49.5 strokes/minute
# * Time: 13.97s

# %% [markdown]
# <video width="500" height="240"
#        src="_data/alon_s5_2.mp4"
#        controls>
#
# </video>

# %% [markdown]
# ## Sam Shorts 400 free final, Fukuoka 2023
# * Cycle-count: 17
# * DPC: 2.35 m/stroke
# * Frequency: 42.8 strokes/minute
# * Time: 25.9s

# %% [markdown]
# ## Sam Shorts 800 free final, Fukuoka 2023
# * Cycle-count: 16
# * DPC: 2.5 m/cycle
# * Frequency: 40.5 strokes/minute
# * Time: 27.2s

# %% [markdown]
# # Insights

# %% [markdown]
# 1. It seems that in the begining, Alon found it challenging to swim with the tempo-trainer.
# 1. Although the high-frequencies ($\sim50\frac{cycles}{minute}$) are not in Alon's comphort zone, we can see a really steep direvative of the speed as a function of frequency function (if I comphortly ignore several swims which I consider as outliers).
# 1. I would like to see a sample-race of Alon, to test for his DPS/frequency at a race, since it is very much likely that Alon's optimal freuquency is not the "standard" $\sim40\frac{cycles}{minute}$.
# 1. With taking the physical toll of increasing frequency into considiration of course, I would like to test that theory.
