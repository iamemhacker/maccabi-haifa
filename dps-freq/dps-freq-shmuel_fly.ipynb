# %%
import pandas as pd
from toolkit.utils import prepare_dps_freq, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured speed.
#
# ## Note
# The _Time_ columns represents the time of the surfaced swimming only, whereas the _Speed_ column is $25m$ divided by the total lap time - surfaced and submerged swimming.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Shmuel (fly)

# %%
import numpy as np


df_raw = pd.read_csv("shmuel_fly/data.csv")  
df_data = prepare_dps_freq(df_raw)

# %% [markdown]
# #

# %% [markdown]
# # Display

# %%
display(df_data.sort_values("Frequency"))
display_analysis(df_data)
# Out:
#    Frequency  Num strokes     Speed    Time
# 2  33.620509            8  1.190726  14.277
# 1  34.602076            7  1.400560  12.138
# 4  37.386505            7  1.557771  11.234
# 0  37.824207            7  1.576009  11.104
# 5  40.291635            7  1.630852  10.424
# 6  40.947646            7  1.657405  10.257
# 3  45.214770            8  1.554258  10.616
#    Frequency  Num strokes     Speed    Time
# 6  40.947646            7  1.657405  10.257
# 5  40.291635            7  1.630852  10.424
# 0  37.824207            7  1.576009  11.104
# 4  37.386505            7  1.557771  11.234
# 3  45.214770            8  1.554258  10.616
# 1  34.602076            7  1.400560  12.138
# 2  33.620509            8  1.190726  14.277
#              Frequency  Num strokes
# Frequency     1.000000     0.148065
# Num strokes   0.148065     1.000000
#              Num strokes      Time
# Num strokes     1.000000  0.492341
# Time            0.492341  1.000000

# %%
display(df_raw)
# Out:
#    measurement  interval-time  id  distance
# 0     breakout          3.021   1       7.5
# 1        cycle          0.602   1       NaN
# 2        cycle          1.468   1       NaN
# 3        cycle          1.503   1       NaN
# 4        cycle          1.563   1       NaN
# 5        cycle          1.573   1       NaN
# 6        cycle          1.455   1       NaN
# 7        cycle          2.940   1       NaN
# 8     breakout          2.958   2       8.0
# 9        cycle          0.884   2       NaN
# 10       cycle          1.559   2       NaN
# 11       cycle          1.561   2       NaN
# 12       cycle          1.518   2       NaN
# 13       cycle          1.625   2       NaN
# 14       cycle          1.791   2       NaN
# 15       cycle          3.200   2       NaN
# 16       cycle          1.721   3       8.0
# 17       cycle          1.075   3       NaN
# 18       cycle          1.716   3       NaN
# 19       cycle          1.566   3       NaN
# 20       cycle          1.451   3       NaN
# 21       cycle          1.454   3       NaN
# 22       cycle          1.494   3       NaN
# 23       cycle          3.800   3       NaN
# 24    breakout          3.104   4       8.5
# 25       cycle          0.761   4       NaN
# 26       cycle          1.405   4       NaN
# 27       cycle          1.339   4       NaN
# 28       cycle          1.435   4       NaN
# 29       cycle          1.439   4       NaN
# 30       cycle          1.481   4       NaN
# 31       cycle          1.438   4       NaN
# 32       cycle          1.318   4       NaN
# 33    breakout          2.712   5       7.5
# 34       cycle          0.721   5       NaN
# 35       cycle          1.429   5       NaN
# 36       cycle          1.373   5       NaN
# 37       cycle          1.496   5       NaN
# 38       cycle          1.550   5       NaN
# 39       cycle          1.565   5       NaN
# 40       cycle          3.100   5       NaN
# 41    breakout          2.927   6       8.0
# 42       cycle          0.538   6       NaN
# 43       cycle          1.276   6       NaN
# 44       cycle          1.346   6       NaN
# 45       cycle          1.341   6       NaN
# 46       cycle          1.514   6       NaN
# 47       cycle          1.293   6       NaN
# 48       cycle          3.116   6       NaN
# 49    breakout          3.086   7       8.0
# 50       cycle          0.655   7       NaN
# 51       cycle          1.472   7       NaN
# 52       cycle          1.284   7       NaN
# 53       cycle          1.286   7       NaN
# 54       cycle          1.547   7       NaN
# 55       cycle          1.341   7       NaN
# 56       cycle          2.672   7       NaN
