# %%
import pandas as pd
from toolkit.utils import prepare_dps_freq, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured speed.
#
# ## Note
# The _Time_ columns represents the time of the surfaced swimming only, whereas the _Speed_ column is $25m$ divided by the total lap time - surfaced and submerged swimming.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Tal (free)

# %%
import numpy as np


df_raw = pd.read_excel("omer/raw-data2.xlsx")
df_data = prepare_dps_freq(df_raw)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'measurement'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> df_raw = pd.read_excel("omer/raw-data2.xlsx")
# ----> <a href='vscode-notebook-cell:/Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> df_data = prepare_dps_freq(df_raw)
#
# File ~/work/maccabi-haifa/dps-freq/toolkit/utils.py:57, in prepare_dps_freq(df)
#      51 def prepare_dps_freq(df: pd.DataFrame) -> pd.DataFrame:
#      52     colnames = {
#      53         "measurement": "measurement",
#      54         "time": "interval-time",
#      55         "speed": "Speed",
#      56         }
# ---> 57     df_cycles = df.loc[df[colnames["measurement"]] == "cycle"]
#      58     # Frequency.
#      59     df_freq = 60 / df_cycles.groupby("id", as_index=False).mean(colnames["time"])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'measurement'

# %% [markdown]
# #

# %% [markdown]
# # Display

# %%
display(df_data.sort_values("Frequency"))
display_analysis(df_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> display(df_data.sort_values("Frequency"))
#       <a href='vscode-notebook-cell:/Users/eliormalul/work/maccabi-haifa/dps-freq/dps-freq-tal.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> display_analysis(df_data)
#
# NameError: name 'df_data' is not defined

# %%
display(df_raw)
# Out:
#    measurement  interval-time  id  distance
# 0     breakout          1.422   1       5.0
# 1        cycle          1.039   1       NaN
# 2        cycle          1.575   1       NaN
# 3        cycle          1.649   1       NaN
# 4        cycle          1.721   1       NaN
# 5        cycle          1.767   1       NaN
# 6        cycle          1.494   1       NaN
# 7        cycle          1.780   1       NaN
# 8        cycle          1.724   1       NaN
# 9        cycle          1.799   1       NaN
# 10    breakout          1.601   2       5.0
# 11       cycle          0.995   2       NaN
# 12       cycle          1.596   2       NaN
# 13       cycle          1.659   2       NaN
# 14       cycle          1.848   2       NaN
# 15       cycle          1.690   2       NaN
# 16       cycle          1.565   2       NaN
# 17       cycle          1.783   2       NaN
# 18       cycle          1.624   2       NaN
# 19       cycle          1.888   2       NaN
# 20       cycle          1.910   2       NaN
# 21    breakout          1.500   3       5.0
# 22       cycle          0.769   3       NaN
# 23       cycle          1.621   3       NaN
# 24       cycle          1.628   3       NaN
# 25       cycle          1.741   3       NaN
# 26       cycle          1.771   3       NaN
# 27       cycle          1.677   3       NaN
# 28       cycle          1.685   3       NaN
# 29       cycle          1.738   3       NaN
# 30       cycle          2.000   3       NaN
# 31       cycle          1.119   3       NaN
# 32    breakout          1.383   4       5.0
# 33       cycle          1.274   4       NaN
# 34       cycle          1.570   4       NaN
# 35       cycle          1.583   4       NaN
# 36       cycle          1.906   4       NaN
# 37       cycle          1.799   4       NaN
# 38       cycle          1.927   4       NaN
# 39       cycle          1.577   4       NaN
# 40       cycle          2.080   4       NaN
# 41       cycle          1.867   4       NaN
# 42       cycle          1.149   4       NaN
