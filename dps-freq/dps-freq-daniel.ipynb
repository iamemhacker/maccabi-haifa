# %%
from toolkit.utils import read_data, display_analysis

# %% [markdown]
# ## Introduction
#
# This experiment is the first phase of our endevour to optimize the frontend of the race.
# This optimization effort is done in a situation in which maximizing will hurt us on others.
# (_e.g._, increasing frequency in most cases will favor the split time on one hand,
# and would hurt the DPS as well as the physical condition of the swimmer).
#
# ## About the results
#
# Our experiment is consisted of 4-5 time of pairs of $25m$ interval, in linearily increasing cycle frequency.
# The $X$ axis is the frequency (mesearued in cycles/minute),
# the $Y$ axis represents the Distance-per-stroke (DPS), whereas the $Z$ axis is the measured time.
#
# The experiment was done in a standard SCM pool.

# %% [markdown]
# ## Daniel (Freestyle)

# %%
display_analysis(read_data("_data/raw-data.csv", "Daniel"))
# Out:
#    Swimmer Name       Freq  Cycle time  Num strokes   Time       DPS     Speed
# 63       Daniel  53.074979    1.130476         10.5  11.87  1.428571  1.637197
# 67       Daniel  47.224524    1.270526          9.5  12.07  1.578947  1.616031
# 62       Daniel  50.888530    1.179048         10.5  12.38  1.428571  1.584284
# 64       Daniel  47.694754    1.258000         10.0  12.58  1.500000  1.564456
# 66       Daniel  44.776119    1.340000          9.5  12.73  1.578947  1.549907
# 65       Daniel  46.189376    1.299000         10.0  12.99  1.500000  1.525320
# 68       Daniel  43.846154    1.368421          9.5  13.00  1.578947  1.524390
#                 Freq  Num strokes
# Freq         1.00000      0.88878
# Num strokes  0.88878      1.00000
#              Num strokes      Time
# Num strokes     1.000000 -0.438252
# Time           -0.438252  1.000000

# %% [markdown]
# Notice - the times in the table above are net-surface time, w/o the uw time.

# %% [markdown]
# ## Daniel 25m Free (Fq-46)
# * Cycles: 10
# * DPC (Distance-per-cycle): 1.9 m/cycle
# * Frequency: 46 strokes/minute
# * Time: 15.5s

# %% [markdown]
# ## Daniel 25m Free (Fq-50.8)
# * Cycles: 10.5
# * DPC (Distance-per-cycle): 1.8 m/cycle
# * Frequency: 50.8 strokes/minute
# * Time: 14.8s

# %% [markdown]
# ## Sam Shorts 400 free final, Fukuoka 2023
# * Cycle-count: 17
# * DPC: 2.35 m/stroke
# * Frequency: 42.8 strokes/minute
# * Time: 25.9s

# %% [markdown]
# ## Sam Shorts 800 free final, Fukuoka 2023
# * Cycle-count: 16
# * DPC: 2.5 m/cycle
# * Frequency: 40.5 strokes/minute
# * Time: 27.2s

# %% [markdown]
# # Insights

# %% [markdown]
# 1. Daniel has an ability to swim in high frequencies ($\ge 50$) which is great.
# 1. As a general say, it would be greate to see Daniel improve his DPS (to $l \ge 2m$) for starters.
# 1. We need to "flatten the hump" of that DPS-FREQ-SPEED shape around the frequency of 46,
# so the speed increase from the lower frequencies ($\sim40$) to the higher will be linear.
# This will allow Daniel to swim the mid-long distances faster.
